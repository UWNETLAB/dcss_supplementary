# %% [markdown]
# # <font color="#49699E" size=40>Processing Structured Data</font>

# %% [markdown]
# # LEARNING OBJECTIVES
# # LEARNING MATERIALS

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# ## Imports

# %%
import pandas as pd
pd.set_option("display.notebook_repr_html", False)

# %% [markdown]
# ## PRACTICAL PANDAS: FIRST STEPS

# %% [markdown]
# ### Getting Data into Pandas

# %%
df = pd.read_csv('../data/vdem/V-Dem-CY-Full+Others-v10.csv', low_memory=False)

# %%
df.shape
# Out:
# (27013, 48)

# %% [markdown]
# ### What Do You Need? Selecting Columns

# %%
subset_vars = ['country_name', 'country_text_id', 'e_regiongeo', 'year', 'v2x_polyarchy', 'v2x_libdem', 'v2x_partipdem', 'v2x_delibdem', 'v2x_egaldem', 'v2smprivex', 'v2smpolsoc', 'v2caviol', 'e_boix_regime']
sdf = df[subset_vars]
sdf.shape
# Out:
# (27013, 13)

# %%
list(sdf.columns)
# Out:
# ['country_name',
#  'country_text_id',
#  'e_regiongeo',
#  'year',
#  'v2x_polyarchy',
#  'v2x_libdem',
#  'v2x_partipdem',
#  'v2x_delibdem',
#  'v2x_egaldem',
#  'v2smprivex',
#  'v2smpolsoc',
#  'v2caviol',
#  'e_boix_regime']

# %% [markdown]
# #### What's in Your dataframe?

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27013 entries, 0 to 27012
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_name     27013 non-null  object
#  1   country_text_id  27013 non-null  object
#  2   e_regiongeo      27013 non-null  int64
#  3   year             27013 non-null  int64
#  4   v2x_polyarchy    25342 non-null  float64
#  5   v2x_libdem       24350 non-null  float64
#  6   v2x_partipdem    24923 non-null  float64
#  7   v2x_delibdem     18557 non-null  float64
#  8   v2x_egaldem      18557 non-null  float64
#  9   v2smprivex       3562 non-null   float64
#  10  v2smpolsoc       3562 non-null   float64
#  11  v2caviol         12745 non-null  float64
#  12  e_boix_regime    16270 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 2.7+ MB

# %%
sdf[['e_regiongeo', 'year', 'v2x_polyarchy']].describe()
# Out:
#         e_regiongeo          year  v2x_polyarchy
# count  27013.000000  27013.000000   25342.000000
# mean       9.266575   1926.556177       0.262821
# std        5.733007     63.754335       0.260966
# min        1.000000   1789.000000       0.007000
# 25%        4.000000   1878.000000       0.057000
# 50%        8.000000   1937.000000       0.171500
# 75%       14.000000   1980.000000       0.367000
# max       19.000000   2019.000000       0.924000

# %% [markdown]
# ### Heads, Tails, and Samples

# %%
sdf[['country_name', 'year', 'v2x_libdem']].head()
# Out:
#   country_name  year  v2x_libdem
# 0       Mexico  1789       0.043
# 1       Mexico  1790       0.040
# 2       Mexico  1791       0.040
# 3       Mexico  1792       0.040
# 4       Mexico  1793       0.040

# %%
sdf[['country_name', 'year', 'v2x_libdem']].tail(3)
# Out:
#             country_name  year  v2x_libdem
# 27010  Piedmont-Sardinia  1859       0.150
# 27011  Piedmont-Sardinia  1860       0.148
# 27012  Piedmont-Sardinia  1861       0.149

# %%
sdf[['country_name', 'year', 'v2x_libdem']].sample(15)
# Out:
#                 country_name  year  v2x_libdem
# 22802             Montenegro  1813         NaN
# 26794              Oldenburg  1842         NaN
# 19519               Barbados  1943       0.186
# 17339             Kazakhstan  2009       0.133
# 16264  Republic of the Congo  1914       0.047
# 25894                  Parma  1850       0.114
# 22005                 Kuwait  1893         NaN
# 20984                   Fiji  1944       0.194
# 8240               Indonesia  1922       0.030
# 4524                    Peru  1863       0.123
# 11372                Germany  1799       0.067
# 19841               Bulgaria  1898       0.201
# 3681                 Bolivia  1857       0.072
# 18635                   Togo  2003       0.152
# 654              Switzerland  1870       0.465

# %% [markdown]
# ### What Do You Need? Filtering Rows

# %%
rowfilter = sdf['year'] >= 1900
fsdf = sdf[rowfilter].copy()
fsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18787 entries, 111 to 25622
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_name     18787 non-null  object
#  1   country_text_id  18787 non-null  object
#  2   e_regiongeo      18787 non-null  int64
#  3   year             18787 non-null  int64
#  4   v2x_polyarchy    18663 non-null  float64
#  5   v2x_libdem       18424 non-null  float64
#  6   v2x_partipdem    18587 non-null  float64
#  7   v2x_delibdem     18557 non-null  float64
#  8   v2x_egaldem      18557 non-null  float64
#  9   v2smprivex       3562 non-null   float64
#  10  v2smpolsoc       3562 non-null   float64
#  11  v2caviol         12745 non-null  float64
#  12  e_boix_regime    11841 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 2.0+ MB

# %%
alternate_fsdf = sdf.query('year >= 1900').copy()
alternate_fsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18787 entries, 111 to 25622
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_name     18787 non-null  object
#  1   country_text_id  18787 non-null  object
#  2   e_regiongeo      18787 non-null  int64
#  3   year             18787 non-null  int64
#  4   v2x_polyarchy    18663 non-null  float64
#  5   v2x_libdem       18424 non-null  float64
#  6   v2x_partipdem    18587 non-null  float64
#  7   v2x_delibdem     18557 non-null  float64
#  8   v2x_egaldem      18557 non-null  float64
#  9   v2smprivex       3562 non-null   float64
#  10  v2smpolsoc       3562 non-null   float64
#  11  v2caviol         12745 non-null  float64
#  12  e_boix_regime    11841 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Writing Data to Disk

# %%
fsdf.to_csv('../data/vdem/filtered_subset.csv', index=False)

# %% [markdown]
# ## UNDERSTANDING PANDAS DATA STRUCTURES

# %% [markdown]
# ### The `Series`

# %%
fsdf['v2x_delibdem'].sample(15, random_state = 42)
# Out:
# 8437     0.305
# 25197    0.059
# 6661     0.079
# 19266    0.390
# 7633     0.632
# 1230     0.727
# 8829     0.020
# 10118    0.008
# 8996     0.047
# 2360     0.048
# 18407    0.018
# 153      0.132
# 10794    0.805
# 14375    0.800
# 24240      NaN
# Name: v2x_delibdem, dtype: float64

# %%
fsdf.index
# Out:
# Index([  111,   112,   113,   114,   115,   116,   117,   118,   119,   120,
#        ...
#        25613, 25614, 25615, 25616, 25617, 25618, 25619, 25620, 25621, 25622],
#       dtype='int64', length=18787)

# %% [markdown]
# #### Accessing a Specific Row by its Index

# %%
fsdf.loc[202]
# Out:
# country_name       Mexico
# country_text_id       MEX
# e_regiongeo            17
# year                 1991
# v2x_polyarchy       0.435
# v2x_libdem          0.221
# v2x_partipdem       0.246
# v2x_delibdem         0.31
# v2x_egaldem         0.214
# v2smprivex            NaN
# v2smpolsoc            NaN
# v2caviol            -0.71
# e_boix_regime         0.0
# Name: 202, dtype: object

# %%
fsdf['v2x_delibdem'].loc[202]
# Out:
# np.float64(0.31)

# %%
fsdf['v2x_delibdem'].loc[20000]
# Out:
# np.float64(0.081)

# %%
fsdf.iloc[18786]
# Out:
# country_name       Zanzibar
# country_text_id         ZZB
# e_regiongeo               8
# year                   2019
# v2x_polyarchy         0.245
# v2x_libdem             0.18
# v2x_partipdem         0.083
# v2x_delibdem          0.183
# v2x_egaldem           0.187
# v2smprivex           -1.843
# v2smpolsoc           -0.848
# v2caviol             -0.181
# e_boix_regime           NaN
# Name: 25622, dtype: object

# %%
fsdf.reset_index(inplace = True, drop = True)
fsdf.loc[18786]
# Out:
# country_name       Zanzibar
# country_text_id         ZZB
# e_regiongeo               8
# year                   2019
# v2x_polyarchy         0.245
# v2x_libdem             0.18
# v2x_partipdem         0.083
# v2x_delibdem          0.183
# v2x_egaldem           0.187
# v2smprivex           -1.843
# v2smpolsoc           -0.848
# v2caviol             -0.181
# e_boix_regime           NaN
# Name: 18786, dtype: object

# %% [markdown]
# ### Dataframes

# %%
deliberative = fsdf['v2x_delibdem']

# %%
fsdf['21 Century'] = fsdf['year'] >= 2000
fsdf[['21 Century']].value_counts()
# Out:
# 21 Century
# False         15225
# True           3562
# Name: count, dtype: int64

# %%
fsdf['missing_political_violence_data'] = fsdf['v2caviol'].isna()
fsdf['missing_political_violence_data'].value_counts()
# Out:
# missing_political_violence_data
# False    12745
# True      6042
# Name: count, dtype: int64

# %% [markdown]
# ### Missing Data

# %%
import numpy as np

type(np.nan)
# Out:
# float

# %%
n = np.nan 
n == n
# Out:
# False

# %%
if np.nan is None: 
    print('NaN is None') 
if np.nan: 
    print('NaN evaluates to True in control flow') 
if np.isnan(np.nan): 
    print('NaN is considered a NaN value in NumPy')
# Out:
# NaN evaluates to True in control flow
# NaN is considered a NaN value in NumPy

# %%
total = len(fsdf['v2caviol']) 
count = fsdf['v2caviol'].count() 
print(f'Total: {total}') 
print(f'Count: {count}') 
print(f'Diff: {total-count}')
# Out:
# Total: 18787
# Count: 12745
# Diff: 6042

# %%
nans = fsdf['v2caviol'].isna().sum() 
print(' NaNs: {}'.format(nans))
# Out:
#  NaNs: 6042

# %% [markdown]
# ## AGGREGATION & GROUPED OPERATIONS

# %%
grouped = fsdf.groupby('e_regiongeo')

# %%
south_east_asia = grouped.get_group(13)
south_east_asia[['country_name', 'year', 'e_boix_regime']].head()
# Out:
#       country_name  year  e_boix_regime
# 838  Burma/Myanmar  1900            NaN
# 839  Burma/Myanmar  1901            NaN
# 840  Burma/Myanmar  1902            NaN
# 841  Burma/Myanmar  1903            NaN
# 842  Burma/Myanmar  1904            NaN

# %%
poly = grouped['v2x_polyarchy'].median()
poly.head()
# Out:
# e_regiongeo
# 1    0.7940
# 2    0.8170
# 3    0.3890
# 4    0.2385
# 5    0.0955
# Name: v2x_polyarchy, dtype: float64

# %%
regions = {
    1:'Western Europe',
    2:'Northern Europe',
    3:'Southern Europe',
    4:'Eastern Europe',
    5:'Northern Africa',
    6:'Western Africa',
    7:'Middle Africa',
    8:'Eastern Africa',
    9:'Southern Africa',
    10:'Western Asia',
    11:'Central Asia',
    12:'East Asia',
    13:'South-East Asia',
    14:'South Asia',
    15:'Oceania', # (including Australia and the Pacific)
    16:'North America',
    17:'Central America',
    18:'South America',
    19:'Caribbean' # (including Belize Cuba Haiti Dominican Republic)
}

# %%
fsdf['Region'] = fsdf['e_regiongeo'].map(regions)

# %%
grouped = fsdf.groupby(['Region', 'year'])
poly = grouped['v2x_polyarchy'].median()
poly.reset_index()
pd.DataFrame(poly).reset_index().sample(10)
# Out:
#                Region  year  v2x_polyarchy
# 429    Eastern Africa  1918         0.0340
# 307         East Asia  1916         0.0685
# 1260    South America  1909         0.2060
# 1933   Western Africa  1982         0.1600
# 132   Central America  1912         0.1760
# 2100   Western Europe  1909         0.4745
# 1006  Northern Africa  2015         0.2875
# 1524  South-East Asia  1933         0.0725
# 420    Eastern Africa  1909         0.0380
# 1136          Oceania  1905         0.2040

# %%
grouped.size().sort_values(ascending=False)
# Out:
# Region          year
# Eastern Africa  2015    20
#                 2012    20
#                 2019    20
#                 2018    20
#                 2017    20
#                         ..
# Central Asia    1904     1
#                 1903     1
#                 1902     1
#                 1901     1
#                 1914     1
# Length: 2211, dtype: int64

# %%
with_agg = grouped['v2x_polyarchy'].agg([min, np.median, 'max', 'count'])
with_agg.reset_index().sample(10)
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_45353/987154122.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   with_agg = grouped['v2x_polyarchy'].agg([min, np.median, 'max', 'count'])
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_45353/987154122.py:1: FutureWarning: The provided callable <function median at 0x1100accc0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   with_agg = grouped['v2x_polyarchy'].agg([min, np.median, 'max', 'count'])
#                Region  year    min  median    max  count
# 2150   Western Europe  1959  0.170  0.7675  0.844      8
# 1417       South Asia  1946  0.016  0.1360  0.345      7
# 215   Central America  1995  0.424  0.5650  0.870      7
# 351         East Asia  1960  0.070  0.1650  0.862      7
# 499    Eastern Africa  1988  0.072  0.1920  0.781     17
# 1575  South-East Asia  1984  0.070  0.1725  0.336     10
# 1253    South America  1902  0.031  0.2115  0.358     12
# 378         East Asia  1987  0.089  0.1990  0.831      7
# 808     North America  1937  0.567  0.6290  0.691      2
# 196   Central America  1976  0.110  0.1790  0.806      7

# %% [markdown]
# ## WORKING WITH TIME SERIES DATA

# %%
"Monday Mar 2, 1999" > "Friday Feb 21, 2020"
# Out:
# True

# %%
import os
data_dir = os.listdir("../data/russian-troll-tweets/")

files = [f for f in data_dir if 'csv' in f]

tweets_df = pd.concat((pd.read_csv(
    f'{"../data/russian-troll-tweets/"}/{f}', 
    encoding='utf-8', low_memory=False) for f in files), ignore_index=True)

tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2946207 entries, 0 to 2946206
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   external_author_id  object
#  1   author              object
#  2   content             object
#  3   region              object
#  4   language            object
#  5   publish_date        object
#  6   harvested_date      object
#  7   following           int64
#  8   followers           int64
#  9   updates             int64
#  10  post_type           object
#  11  account_type        object
#  12  retweet             int64
#  13  account_category    object
#  14  new_june_2018       int64
#  15  alt_external_id     object
#  16  tweet_id            int64
#  17  article_url         object
#  18  tco1_step1          object
#  19  tco2_step1          object
#  20  tco3_step1          object
# dtypes: int64(6), object(15)
# memory usage: 472.0+ MB

# %%
tweets_df['dt_publish_date'] = pd.to_datetime(tweets_df['publish_date'])
tweets_df['dt_harvested_date'] = pd.to_datetime(tweets_df['harvested_date'])

# %%
tweets_df[['author', 'content', 'publish_date']].sample(5)
# Out:
#                   author                                            content  \
# 2669597       NEW_INF0RM  Эстонцы, подвиньтесь: солдаты НАТО «выжили» ме...
# 1441774  DAILYNEWSDENVER  Thunderstorms, scattered rain will cool off De...
# 405841    GALLOWAYELIANA  Today noon #buybacktheblock video. @gucci1017 ...
# 1637409       ANNSAM_SAM  К берегам Японии прибило 11 деревянных лодок с...
# 1589149         AMIISTRS  #amms Look Who Called for the Assassination of...
#
#             publish_date
# 2669597   3/25/2017 4:45
# 1441774  7/28/2017 13:25
# 405841   12/2/2016 19:32
# 1637409  12/1/2015 19:13
# 1589149  8/13/2017 16:01

# %%
tweets_df['dt_publish_date'].dt.month
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 2946202    2
# 2946203    2
# 2946204    2
# 2946205    2
# 2946206    2
# Name: dt_publish_date, Length: 2946207, dtype: int32

# %%
sorted_df = tweets_df.sort_values(['dt_publish_date'])

# %%
tweets_df['days_until_harvest'] = tweets_df['dt_harvested_date'] - tweets_df['dt_publish_date']
tweets_df['days_until_harvest'].sample(10)
# Out:
# 2658817   0 days 00:01:00
# 2122942   0 days 00:00:00
# 1712079   0 days 00:00:00
# 1460965   0 days 00:01:00
# 564354    0 days 00:00:00
# 146071    0 days 00:00:00
# 2694763   0 days 00:00:00
# 1258396   0 days 00:00:00
# 1033642   0 days 00:01:00
# 1868776   0 days 00:00:00
# Name: days_until_harvest, dtype: timedelta64[ns]

# %%
tweets_df['Year'] = tweets_df['dt_publish_date'].dt.year
tweets_df['Month'] = tweets_df['dt_publish_date'].dt.month
tweets_df['Day'] = tweets_df['dt_publish_date'].dt.day

# %%
tweets_df = tweets_df.set_index('dt_publish_date')

# %%
grouped_cal_day = tweets_df.resample('D').size()
grouped_cal_day
# Out:
# dt_publish_date
# 2012-02-02     4
# 2012-02-03     0
# 2012-02-04     1
# 2012-02-05     1
# 2012-02-06     3
#               ..
# 2018-05-26    44
# 2018-05-27    49
# 2018-05-28    43
# 2018-05-29    49
# 2018-05-30    32
# Freq: D, Length: 2310, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from dcss.plotting import custom_seaborn
custom_seaborn()

# %%
sns.lineplot(data=grouped_cal_day, color='#32363A')
sns.despine()
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_45353/862655744.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
weekly = tweets_df.resample('W').size()
weekly.head()
# Out:
# dt_publish_date
# 2012-02-05     6
# 2012-02-12    14
# 2012-02-19     5
# 2012-02-26    11
# 2012-03-04     1
# Freq: W-SUN, dtype: int64

# %%
ax = sns.lineplot(data=weekly, color='#32363A')
ax.set_xlabel('\nWeekly observations')
ax.set_ylabel('Number of Tweets\n')
sns.despine()
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_45353/942700106.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## COMBINING DATAFRAMES

# %%
full_df =  pd.read_csv("../data/vdem/filtered_subset.csv")
df_australia = full_df.query("country_name == 'Australia'")
len(df_australia)
# Out:
# 120

# %%
df_sa = full_df.query("country_name == 'South Africa'")
len(df_sa)
# Out:
# 120

# %%
concatenated = pd.concat([df_australia, df_sa], axis=1)
len(concatenated)
# Out:
# 240

# %% [markdown]
# ### Merging

# %%
freedom_df = pd.read_csv( "../data/freedom_house/internet_freedoms_2020.csv")

# %%
fsdf.columns
# Out:
# Index(['country_name', 'country_text_id', 'e_regiongeo', 'year',
#        'v2x_polyarchy', 'v2x_libdem', 'v2x_partipdem', 'v2x_delibdem',
#        'v2x_egaldem', 'v2smprivex', 'v2smpolsoc', 'v2caviol', 'e_boix_regime',
#        '21 Century', 'missing_political_violence_data', 'Region'],
#       dtype='object')

# %%
freedom_df.columns
# Out:
# Index(['Country', 'Total Score', 'Status', 'Obstacles to Access',
#        'Limits on Content', 'Violations of User Rights'],
#       dtype='object')

# %%
merged = pd.merge(fsdf, freedom_df, how='inner', left_on='country_name', right_on='Country')
print('merged has {} rows and {} columns'.format(len(merged), len(merged.columns)))
# Out:
# merged has 6434 rows and 22 columns

# %%
len(fsdf) + len(freedom_df)
# Out:
# 18852

# %%
fsdf_set = set(fsdf['country_name'].tolist())
freedom_set = set(freedom_df['Country'].tolist())

unmatched = fsdf_set ^ freedom_set

print('Total countries: ' + str(len(fsdf_set) + len(freedom_set)))
print('Unmatched countries: ' + str(len(unmatched)))
# Out:
# Total countries: 248
# Unmatched countries: 122

# %%
fsdf_missing = list(fsdf_set & unmatched)
fsdf_missing.sort()
freedom_missing = list(freedom_set & unmatched)
freedom_missing.sort()
pd.DataFrame({'VDEM': pd.Series(fsdf_missing), 'Freedom': pd.Series(freedom_missing)})
# Out:
#                          VDEM        Freedom
# 0                 Afghanistan        Myanmar
# 1                     Albania  United States
# 2                     Algeria            NaN
# 3                     Austria            NaN
# 4                    Barbados            NaN
# ..                        ...            ...
# 115  United States of America            NaN
# 116                   Uruguay            NaN
# 117                   Vanuatu            NaN
# 118                     Yemen            NaN
# 119                  Zanzibar            NaN
#
# [120 rows x 2 columns]

# %% [markdown]
# ### Record Linkage

# %% [markdown]
# # CONCLUSION
# ## Key Points
