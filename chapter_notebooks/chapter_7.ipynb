# %% [markdown]
# # <font color="#49699E" size=40>Visualization & Exploratory Data Analysis</font>

# %% [markdown]
# # LEARNING OUTCOMES
# # LEARNING MATERIALS

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# # ITERATIVE RESEARCH WORKFLOWS: EDA AND BOX'S LOOP

# %% [markdown]
# # EFFECTIVE VISUALIZATION

# %% [markdown]
# ### Guidelines for Effective Visualization

# %% [markdown]
# # UNIVARIATE EDA: DESCRIBING AND VISUALIZING DISTRIBUTIONS

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
pd.set_option("display.notebook_repr_html", False)
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from dcss.plotting import format_axes_commas, custom_seaborn
custom_seaborn()

fsdf = pd.read_csv('../data/vdem/filtered_subset.csv') 
fsdf.shape
# Out:
# (18787, 13)

# %%
egal = fsdf['v2x_egaldem']
print(f'Median Egalitarian Democracy Score: {egal.median()}')
print(f'Mean Egalitarian Democracy Score: {egal.mean()}')
print(f'Standard Deviation: {egal.std()}')
# Out:
# Median Egalitarian Democracy Score: 0.142
# Mean Egalitarian Democracy Score: 0.2368012609796842
# Standard Deviation: 0.23019217079493423

# %%
print(f'Median Egalitarian Democracy Score: {round(egal.median(),3)}')
print(f'Mean Egalitarian Democracy Score: {round(egal.mean(), 3)}')
print(f'Standard Deviation: {round(egal.std(), 3)}')
# Out:
# Median Egalitarian Democracy Score: 0.142
# Mean Egalitarian Democracy Score: 0.237
# Standard Deviation: 0.23

# %%
list(fsdf['country_name'].unique())[0:10]
# Out:
# ['Mexico',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Ghana',
#  'South Africa',
#  'Japan',
#  'Burma/Myanmar',
#  'Russia',
#  'Albania']

# %%
fsdf['country_name'].value_counts().head(10)
# Out:
# country_name
# Mexico                              120
# Dominican Republic                  120
# Uruguay                             120
# Algeria                             120
# Angola                              120
# China                               120
# Democratic Republic of the Congo    120
# Djibouti                            120
# Eritrea                             120
# Sri Lanka                           120
# Name: count, dtype: int64

# %%
fsdf['country_name'].value_counts().tail(10)
# Out:
# country_name
# Belarus                   30
# Kazakhstan                30
# Kyrgyzstan                30
# Moldova                   30
# Ukraine                   30
# Turkmenistan              30
# North Macedonia           29
# Bosnia and Herzegovina    28
# Kosovo                    21
# South Sudan                9
# Name: count, dtype: int64

# %% [markdown]
# ### Visualizing Marginal Distributions

# %% [markdown]
# #### Count Plots and Frequency Tables for Categorical Variables

# %%
ax = sns.countplot(data=fsdf, y='e_regiongeo', color='darkgray')
sns.despine()
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1017559957.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.countplot(data=fsdf, y='e_regiongeo', color='darkgray',
                   order = fsdf['e_regiongeo'].value_counts().index) 
sns.despine()
ax.set(xlabel='Number of Observations', ylabel='Geographic Region')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1499836150.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
region_strings = {
    1: "Western Europe",
    2: "Northern Europe",
    3: "Southern Europe",
    4: "Eastern Europe",
    5: "Northern Africa",
    6: "Western Africa",
    7: "Middle Africa",
    8: "Eastern Africa",
    9: "Southern Africa",
    10: "Western Asia",
    11: "Central Asia",
    12: "East Asia",
    13: "South-East Asia",
    14: "South Asia",
    15: "Oceania", # (including Australia and the Pacific)
    16: "North America",
    17: "Central America",
    18: "South America",
    19: "Caribbean" # (including Belize, Cuba, Haiti, Dominican Republic and Guyana)
}

# %%
fsdf.replace({'e_regiongeo': region_strings}, inplace=True)

# %%
ax = sns.countplot(data=fsdf, y='e_regiongeo', color='darkgray',
                   order = fsdf['e_regiongeo'].value_counts().index) # orders the bars
sns.despine(left=True)
ax.set(xlabel='Number of Observations', ylabel='')
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}')) # comma formats x-axis
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1511105892.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fsdf['e_regiongeo'].value_counts()
# Out:
# e_regiongeo
# Eastern Africa     2166
# Western Africa     1824
# Western Asia       1762
# South America      1440
# South-East Asia    1231
# Southern Europe    1011
# Northern Europe     975
# Middle Africa       966
# South Asia          962
# Western Europe      876
# Central America     837
# Eastern Europe      802
# East Asia           784
# Caribbean           720
# Oceania             720
# Northern Africa     700
# Southern Africa     600
# North America       240
# Central Asia        171
# Name: count, dtype: int64

# %% [markdown]
# #### Univariate Histograms and Density Estimation

# %%
ax = sns.histplot(data=fsdf, x='v2x_egaldem')
sns.despine(left=True, right=True, top=True)
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Count')
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/290864372.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.histplot(data=fsdf, x='v2x_egaldem', bins=3)
sns.despine(left=True, right=True, top=True)
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Count')
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/357282294.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.histplot(data=fsdf, x='v2x_egaldem', binwidth = 0.001)
sns.despine(left=True, right=True, top=True)
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Count')
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/2619669415.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.histplot(data=fsdf, x='v2x_egaldem', kde=True)
sns.despine(left=True, right=True, top=True)
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Count')
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1301926456.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# **2026 update:** The original call used `binwidth=4`, but this index only ranges from 0 to 1, so a bin width of 4 rounds to zero bins and current versions of seaborn and NumPy raise a `ValueError`. The bin width is set to `0.1` here to show the effect of a wider bin.

# %%
ax = sns.histplot(fsdf['v2x_egaldem'], kde=True, binwidth=0.1)
sns.despine(left=True, right=True, top=True)
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Count')
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/845690245.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Marginal Empirical Cumulative Distributions

# %% [markdown]
# #### Plotting Empirical Cumulative Distributions

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", kind="ecdf", color='darkgray')
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index')
plt.xlim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/229382905.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # MULTIVARIATE EDA

# %% [markdown]
# ### Visualizing Conditional Distributions

# %% [markdown]
# #### Conditional Histograms

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", col="e_boix_regime", multiple="dodge")
ax.set(xlabel='Egalitarian Democracy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/438636440.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# **2026 update:** The next few plots color a categorical variable (`e_boix_regime`) by a grayscale palette. Current seaborn expects a discrete list of colors here rather than a `Colormap` object, so a two-color `grayscale_palette` is defined alongside the `grayscale_cmap` colormap, which is still used for the correlation heatmaps later on.

# %%
grayscale_cmap = sns.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)
# 2026 update: current seaborn needs a discrete list of colors for a categorical hue,
# so build a two-color palette for the displots below. The colormap above is still used
# for the heatmaps later in the notebook.
grayscale_palette = sns.cubehelix_palette(2, hue=0.05, rot=0, light=0.9, dark=0)

ax = sns.displot(fsdf, x="v2x_egaldem", hue="e_boix_regime", palette=grayscale_palette)
ax.set(xlabel='Egalitarian Democracy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/3021802939.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Conditional KDE

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", hue="e_boix_regime", kde = True, palette=grayscale_palette)
ax.set(xlabel='Egalitarian Democracy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1054638661.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", hue="e_boix_regime", kind = "kde", palette=grayscale_palette)
ax.set(xlabel='Egalitarian Democracy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/3061103607.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Conditional ECDs

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", kind = "ecdf", 
                 hue="e_boix_regime", palette=grayscale_palette)
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index')
plt.xlim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/748130041.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### VISUALIZING JOINT DISTRIBUTIONS

# %% [markdown]
# #### Cross Tables

# %%
ct = pd.crosstab(fsdf.e_regiongeo, fsdf.e_boix_regime)

# %% [markdown]
# #### Scatter Plots

# %%
ax = sns.scatterplot(data = fsdf, x="v2x_egaldem", y="v2x_polyarchy")
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.xlim(0, 1) 
plt.ylim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/101178634.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.scatterplot(data = fsdf, x="v2x_egaldem", y="v2x_polyarchy", alpha = 0.1)
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.xlim(0, 1) 
plt.ylim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/4205097239.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.scatterplot(data = fsdf, x="v2x_egaldem", y="v2x_polyarchy", alpha = 0.01)
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.xlim(0, 1) 
plt.ylim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/2071139108.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Bivariate Histograms

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", y="v2x_polyarchy")
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.xlim(0, 1) 
plt.ylim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/2108514052.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", y="v2x_polyarchy", binwidth = 0.01, rug=True)
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.xlim(0, 1) 
plt.ylim(0, 1) 
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/2003291066.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Bivariate Kernel Density Estimation

# %%
ax = sns.displot(fsdf, x="v2x_egaldem", y="v2x_polyarchy", kind="kde", rug = True, rug_kws = {"alpha": 0.01})
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/76844630.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Line of Best Fit

# %%
ax = sns.regplot(data = fsdf, x = "v2x_egaldem", y = "v2x_polyarchy", color='darkgray', scatter_kws = {"alpha": 0.05}, line_kws={"color": "black"})
sns.despine()
ax.set(xlabel='Egalitarian Democracy Index', ylabel='Polyarchy Index')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/311856903.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Correlation

# %%
corr_libdem_partipdem = fsdf.v2x_libdem.corr(fsdf.v2x_partipdem)
corr_libdem_year = fsdf.v2x_libdem.corr(fsdf.year)

print(f'Correlation of v2x_libdem and v2x_partipdem: {corr_libdem_partipdem}')
print(f'Correlation of v2x_libdem and year: {corr_libdem_year}')
# Out:
# Correlation of v2x_libdem and v2x_partipdem: 0.9699497043536186
# Correlation of v2x_libdem and year: 0.3827966897553839

# %%
df_new = fsdf.copy()
df_new['year_x100'] = fsdf['year'].apply(lambda x: x*100)

new_corr_libdem_partipdem = df_new.v2x_libdem.corr(df_new.v2x_partipdem)
new_corr_libdem_year = df_new.v2x_libdem.corr(df_new.year_x100)

print(f'Correlation of v2x_libdem and v2x_partipdem: {new_corr_libdem_partipdem}')
print(f'Correlation of v2x_libdem and year*100: {new_corr_libdem_year}')
# Out:
# Correlation of v2x_libdem and v2x_partipdem: 0.9699497043536186
# Correlation of v2x_libdem and year*100: 0.3827966897553832

# %% [markdown]
# #### Correlation Coefficient: Pearson and Spearman

# %% [markdown]
# ### Correlation Matrices and Heatmaps

# %%
fsdf_corr = fsdf[['v2x_polyarchy', 'v2x_libdem', 'v2x_partipdem', 'v2x_delibdem', 'v2x_egaldem']].corr()

# %%
ax = sns.heatmap(data = fsdf_corr, vmin = 0.9, vmax = 1, cmap=grayscale_cmap)
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1195340415.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
mask = np.triu(np.ones_like(fsdf_corr, dtype = bool))
ax = sns.heatmap(fsdf_corr, mask = mask, vmin = 0.9, 
                 vmax = 1, cmap=grayscale_cmap)
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1938730736.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Visualization with More Informational Density

# %% [markdown]
# ### Layering Marginal and Joint Distributions

# %%
ax = sns.jointplot(data=fsdf, x="v2x_polyarchy", y="v2x_egaldem", kind="reg", color='darkgray',
              joint_kws={'line_kws':{'color':'black'},
                         'scatter_kws':{'alpha':0.03}})

# %% [markdown]
# ### Quick Comparisons with Pair Plots

# %%
high_level_indexes = ['v2x_polyarchy', 'v2x_libdem', 'v2x_partipdem', 'v2x_delibdem', 'v2x_egaldem']
ax = sns.pairplot(fsdf[high_level_indexes])
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_47120/1623131235.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # CONCLUSION
# ## Key Points
