# %% [markdown]
# # <font color="#49699E" size=40>Influence, Inequality, and Power in Social Networks</font>
# # LEARNING OBJECTIVES
# # LEARNING MATERIALS
# # INTRODUCTION

# %% [markdown]
# ## Package Imports

# %%
import networkx as nx
import pandas as pd
pd.set_option("display.notebook_repr_html", False)
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from dcss.plotting import format_axes_commas, custom_seaborn
from dcss.networks import *
custom_seaborn()

import collections
import random

# %% [markdown]
# ## Data

# %% [markdown]
# **2026 update:** networkx 3 removed `nx.info`. Printing the graph object directly gives an equivalent one-line summary of the number of nodes and edges.

# %%
contact_diaries = pd.read_csv("../data/SocioPatterns/Contact-diaries-network_data_2013.csv", sep=' ')

G = nx.from_pandas_edgelist(contact_diaries, 'i', 'j', create_using=nx.Graph())
G.name = 'Reported Contacts (Diary Data)'
print(G)
# Out:
# Graph named 'Reported Contacts (Diary Data)' with 120 nodes and 348 edges

# %% [markdown]
# # CENTRALITY MEASURES: THE BIG PICTURE

# %% [markdown]
# # SHORTEST PATHS AND NETWORK FLOW

# %% [markdown]
# ## Shortest Paths / Geodesics

# %%
layout = nx.kamada_kawai_layout(G)

# %%
path_a, es_a = get_shortest_paths(G, 173, 48) 
print(path_a)
# Out:
# [173, 295, 954, 691, 642, 605, 687, 496, 134, 45, 48]

# %%
plot_path(G, layout, path_a, es_a)

# %% [markdown]
# ### Multiple Shortest Paths

# %%
sps = [path for path in nx.all_shortest_paths(G, source=173, target=48)]
path_nodes = set([item for sublist in sps for item in sublist])

for path in sps:
    print(path)
# Out:
# [173, 295, 954, 691, 502, 582, 687, 496, 87, 488, 48]
# [173, 295, 954, 691, 642, 582, 687, 496, 87, 488, 48]
# [173, 295, 954, 691, 642, 605, 687, 496, 87, 488, 48]
# [173, 295, 954, 691, 502, 582, 687, 496, 134, 45, 48]
# [173, 295, 954, 691, 642, 582, 687, 496, 134, 45, 48]
# [173, 295, 954, 691, 642, 605, 687, 496, 134, 45, 48]
# [173, 295, 954, 691, 502, 582, 687, 496, 388, 45, 48]
# [173, 295, 954, 691, 642, 582, 687, 496, 388, 45, 48]
# [173, 295, 954, 691, 642, 605, 687, 496, 388, 45, 48]
# [173, 295, 954, 691, 502, 582, 687, 496, 388, 79, 48]
# [173, 295, 954, 691, 642, 582, 687, 496, 388, 79, 48]
# [173, 295, 954, 691, 642, 605, 687, 496, 388, 79, 48]
# [173, 295, 954, 691, 502, 582, 687, 496, 448, 845, 48]
# [173, 295, 954, 691, 642, 582, 687, 496, 448, 845, 48]
# [173, 295, 954, 691, 642, 605, 687, 496, 448, 845, 48]

# %%
fig, ax = plt.subplots(figsize=(12, 8))

nx.draw_networkx_nodes(G, pos=layout, node_size=200, node_color='#32363A')

nx.draw_networkx_edges(G,
                       pos=layout,
                       edge_color='darkgray',
                       width=1)

# the paths!

nx.draw_networkx_nodes(G,
                       pos=layout,
                       node_size=200,
                       node_color='crimson',
                       nodelist=path_nodes)

for p in sps:
    edges = set(zip(p, p[1:]))
    nx.draw_networkx_edges(G,
                           pos=layout,
                           edgelist=edges,
                           edge_color='crimson',
                           width=4)

plt.axis('off')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/4078228226.py:27: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
nx.shortest_path_length(G, source=173, target=48)
# Out:
# 10

# %%
np.round(nx.average_shortest_path_length(G), 2)
# Out:
# np.float64(5.36)

# %% [markdown]
# # BETWEENNESS CENTRALITY, TWO WAYS

# %%
nx.draw(nx.barbell_graph(5,1), node_size=300, node_color='#32363A')

# %%
sp_bet = pd.Series(nx.betweenness_centrality(G))

ax = sns.histplot(sp_bet, kde=True)
ax.set(xlabel='Shortest path betweenness centrality', 
      ylabel='Number of nodes')
sns.despine()
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/2357204041.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
cf_bet = pd.Series(nx.current_flow_betweenness_centrality(G))
betweenness = pd.concat([sp_bet, cf_bet], axis=1)
betweenness.columns = ['Shortest Path Betweenness', 'Current Flow Betweenness']

# %%
sns.jointplot(data=betweenness,
              x='Shortest Path Betweenness',
              y='Current Flow Betweenness',
              alpha=.7)
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/23342389.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # POPULARITY, POWER, AND INFLUENCE

# %%
reported_friendships = pd.read_csv("../data/SocioPatterns/Friendship-network_data_2013.csv",
                                   sep=' ')

G_friendships = nx.from_pandas_edgelist(reported_friendships,
                                        'i', 'j', create_using=nx.DiGraph())

G_friendships.name = 'Reported Friendships'
print(G_friendships)
# Out:
# DiGraph named 'Reported Friendships' with 134 nodes and 668 edges

# %%
layout = nx.nx_pydot.graphviz_layout(G_friendships)

# %% [markdown]
# ## Degree, Degree Centrality, and Connection Inequality

# %%
def visualize_digraph(network, layout, node_size=50, title=''):
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.set_title(title, fontsize=16)
    nx.draw_networkx_nodes(network,
                       pos=layout,
                       node_size=node_size,
                       node_color='#32363A')
    nx.draw_networkx_edges(network,
                       pos=layout,
                       edge_color='#98989C',
                       arrowsize=5,
                       width=1)
    plt.axis('off')
    plt.show()

# %%
in_degree = dict(G_friendships.in_degree())
out_degree = dict(G_friendships.out_degree())

# %%
sized_by_indegree = [v * 20 for v in in_degree.values()]
sized_by_outdegree = [v * 20 for v in out_degree.values()]

# %%
visualize_digraph(G_friendships, layout, sized_by_indegree)
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
visualize_digraph(G_friendships, layout, sized_by_outdegree)
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fig, ax = plt.subplots()
sns.scatterplot(x=in_degree, y=out_degree, alpha = 0.2)
sns.despine()
ax.set(xlabel='Indegree',
       ylabel='Outdegree')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/530547465.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Connection Inequality

# %%
degree_sequence = sorted([d for n, d in G_friendships.degree()], reverse=True)  # degree sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.bar(deg, cnt, width=0.80, color="#32363A")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Degree')
ax.set_ylabel('Number of nodes')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/2045316632.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))

ax.loglog(degree_sequence, 
          'black', 
          marker='o', 
          markersize=3)

plt.title("Degree Rank Plot")
plt.ylabel("Degree")
plt.xlabel("Rank")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Eigenvector Centrality

# %%
def plot_nodes(which_network, which_nodes, what_color, where):
    if type(which_nodes) is list:
        nx.draw_networkx_nodes(which_network, 
                               pos=where, 
                               node_size=100, 
                               node_color=what_color,
                               nodelist=which_nodes) 
    else:
        nx.draw_networkx_nodes(which_network, 
                               pos=where, 
                               node_size=100, 
                               node_color=what_color,
                               nodelist=[which_nodes])

# %%
alters = nx.ego_graph(G_friendships, 1519, radius=1, undirected=True)
alters_2 = nx.ego_graph(G_friendships, 1519, radius=2, undirected=True)

fig, ax = plt.subplots(figsize=(12, 8))
plot_nodes(G_friendships, list(G_friendships.nodes()), 'lightgray', layout)
plot_nodes(G_friendships, list(alters_2.nodes()), 'gray', layout)
plot_nodes(G_friendships, list(alters.nodes()), 'black', layout)
plot_nodes(G_friendships, 1519, 'crimson', layout)

nx.draw_networkx_edges(G_friendships, pos=layout, edge_color='lightgray',
                       arrowsize=3,
                       width=1)

plt.axis('off')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/4064102159.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
alters = nx.ego_graph(G_friendships, 196, radius = 1, undirected = True)
alters_2 = nx.ego_graph(G_friendships, 196, radius = 2, undirected = True)

fig, ax = plt.subplots(figsize=(12,8))
plot_nodes(G_friendships, list(G_friendships.nodes()), 'lightgray', layout)
plot_nodes(G_friendships, list(alters_2.nodes()), 'gray', layout)
plot_nodes(G_friendships, list(alters.nodes()), 'black', layout)
plot_nodes(G_friendships, 196, 'crimson', layout)

nx.draw_networkx_edges(G_friendships, pos=layout, edge_color='lightgray',
                       arrowsize=3,
                       width=1)
plt.axis('off')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/1061835854.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Computing Eigenvector Centrality

# %%
dn = pd.Series(dict(nx.degree(G_friendships)))
ec = pd.Series(nx.eigenvector_centrality(G_friendships))

fig, ax = plt.subplots()
sns.scatterplot(x=dn, y=ec, alpha=.6)
ax.set(xlabel='Degree', ylabel='Eigenvector centrality')
sns.despine()
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/753894833.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Bonacich Power Centrality

# %% [markdown]
# **2026 update:** The original version of this notebook shelled out to an external R script (`power_centrality.R`) to compute Bonacich power centrality and read the results back from `boncent.csv`. That script was never distributed with this repository, so the cells below now compute the same quantity directly in Python: the Bonacich score is alpha * (I - beta * A)^-1 A 1, rescaled so its sum of squares equals the number of nodes, which is the convention used by the R sna package's `bonpow()`. With beta = 0 this reduces to degree centrality, as the first figure shows.

# %%
G = nx.from_pandas_edgelist(contact_diaries, 'i', 'j', create_using=nx.Graph())
G.name = 'Reported Contacts (Diary Data)'

import numpy as np

def bonacich_power_centrality(network, beta):
    A = nx.to_numpy_array(network)
    n = A.shape[0]
    raw = np.linalg.solve(np.eye(n) - beta * A, A.sum(axis=1))
    scaled = raw * np.sqrt(n / (raw @ raw))
    return pd.Series(scaled, index=list(network.nodes()))

# %%
power = pd.DataFrame({
    'b0': bonacich_power_centrality(G, 0.0),
    'b_neg.4': bonacich_power_centrality(G, -0.4),
    'b.4': bonacich_power_centrality(G, 0.4),
})
power = power.round(4)

# %%
layout = nx.nx_pydot.graphviz_layout(G)

def size_by_beta_centrality(network, beta_value, title):
    size = power[beta_value].tolist()
    scale = abs(min(size))+0.0001
    size = [(s+scale)*1000 for s in size]
    visualize_digraph(G, layout, size, title)

# %%
size_by_beta_centrality(G, 'b0', title=r'$\beta$ = 0 (i.e., Degree Centrality)')
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:8: UserWarning:
#
# The arrowsize keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default values.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   nx.draw_networkx_edges(network,
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
size_by_beta_centrality(G, 'b_neg.4', title=r'$\beta$ = -0.4')
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:8: UserWarning:
#
# The arrowsize keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default values.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   nx.draw_networkx_edges(network,
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
size_by_beta_centrality(G, 'b.4', title=r'$\beta$ = 0.4')
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:8: UserWarning:
#
# The arrowsize keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default values.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   nx.draw_networkx_edges(network,
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_53460/3444483469.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # CONCLUSION
# ## Key Points

# %% [markdown]
# # Chapter Appendix
# ## Optional: Formulas for Centrality Measures Covered in this Chapter
# ### Shortest Path Betweenness
# ### Current Flow Betweenness
# ### Eigenvector Centrality
