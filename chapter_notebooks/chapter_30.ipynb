# %% [markdown]
# # <font color="#49699E" size=40>Generative Network Analysis with Bayesian Stochastic Blockmodels</font>
# # LEARNING OUTCOMES
# # LEARNING MATERIALS
# # INTRODUCTION

# %% [markdown]
# ## Latent Network Structure: Connected Communities and Structural Positions

# %% [markdown]
# ### Equivalence?

# %% [markdown]
# ### Blockmodels

# %% [markdown]
# ## Bayesian Hierarchical Stochastic Blockmodels

# %% [markdown]
# # BLOCKMODELLING WITH GRAPH-TOOL

# %% [markdown]
# ## Installing graph-tool

# %% [markdown]
# ## Understanding Property Maps

# %% [markdown]
# ## Imports

# %%
from graph_tool.all import *
import pandas as pd
pd.set_option("display.notebook_repr_html", False)
import matplotlib
import numpy as np
import math
import pickle
from dcss.networks import label_radial_blockmodel, get_block_membership

# %% [markdown]
# ## Data

# %%
edges_df = pd.read_csv('../data/enron/enron_full_edge_list.csv')
edges_df.head()
# Out:
#                       source                             target
# 0    press.release@enron.com            all.worldwide@enron.com
# 1  office.chairman@enron.com             all.downtown@enron.com
# 2  office.chairman@enron.com      all.enron-worldwide@enron.com
# 3    press.release@enron.com            all.worldwide@enron.com
# 4  office.chairman@enron.com  all_enron_north.america@enron.com

# %%
employee_df = pd.read_csv('../data/enron/enron_employees_updated.csv')
employee_df.head()
# Out:
#                            id                  position
# 0        liz.taylor@enron.com  Administrative Assistant
# 1    michelle.lokay@enron.com  Administrative Assistant
# 2  holden.salisbury@enron.com                   Analyst
# 3        kam.keiser@enron.com                   Analyst
# 4   matthew.lenhart@enron.com                   Analyst

# %%
employee_df['position'].value_counts()
# Out:
# position
# Trader                      35
# Vice President              26
# Director                    17
# Manager                     15
# In House Lawyer             11
# Senior Specialist            8
# Managing Director            6
# Specialist                   6
# Employee                     5
# Analyst                      5
# CEO                          4
# President                    4
# Administrative Assistant     2
# Associate                    2
# Senior Manager               1
# COO                          1
# CFO                          1
# Name: count, dtype: int64

# %% [markdown]
# ### Constructing the Communication Network

# %%
edges_df = edges_df.value_counts(['source', 'target']).reset_index(name='count').copy()
core_employees = set(employee_df['id'].tolist())

core_edges_df = edges_df[edges_df['source'].isin(core_employees) & 
                         edges_df['target'].isin(core_employees)]

# %%
eG = Graph(directed = True)

# %%
employee_list = employee_df['id'].tolist()
title_list = employee_df['position'].tolist()

# %%
vertex_lookup = {}

label = eG.new_vertex_property('string')
title = eG.new_vertex_property('string')
edge_weight = eG.new_edge_property('int')

# %%
for vertex in zip(employee_list, title_list):
    # create a new vertex instance
    v = eG.add_vertex()

    # add attributes to the property maps in the index position of the vertex
    label[v] = vertex[0]
    title[v] = vertex[1]

    # add the vertex to the lookup dictionary, converting it to an integer 
    vertex_lookup[vertex[0]] = int(v)

# %%
source_list = core_edges_df['source'].tolist()
target_list = core_edges_df['target'].tolist()
weight_list = core_edges_df['count'].tolist()

for nodes in zip(source_list, target_list, weight_list):
    from_idx = vertex_lookup[nodes[0]]
    to_idx = vertex_lookup[nodes[1]]

    # Let's ignore self-loops
    if from_idx != to_idx:
        edge = eG.add_edge(from_idx, to_idx)
        edge_weight[edge] = nodes[2]

# %%
eG.vertex_properties['label'] = label
eG.vertex_properties['title'] = title
eG.edge_properties['edge_weight'] = edge_weight

lookup = eG.new_graph_property('object')
lookup[eG] = vertex_lookup
eG.graph_properties['vertex_lookup'] = lookup

# %% [markdown]
# ## Developing Stochastic Blockmodels

# %% [markdown]
# **2026 update:** Newer releases of graph-tool changed the signature of `minimize_nested_blockmodel_dl()`. Options such as `deg_corr`, `recs`, and `rec_types` now go inside `state_args`, and block-count bounds such as `B_min` and `B_max` go inside `multilevel_mcmc_args`. The calls in this notebook have been updated; the models and results are the same as in the book.

# %%
state = minimize_nested_blockmodel_dl(eG, state_args=dict(deg_corr=True))

# %%
state.print_summary()
# Out:
# l: 0, N: 149, B: 15
# l: 1, N: 15, B: 3
# l: 2, N: 3, B: 1
# l: 3, N: 1, B: 1

# %%
state.draw(
    layout = "sfdp", 
    vertex_text = eG.vertex_properties['title'], 
    eorder = eG.edge_properties['edge_weight'],
    vertex_text_position = 315,
    bg_color=[255,255,255,1],
    output_size=[4024,4024],
    output='../figures/core_enron_blockmodel_sfdp.png'
    )
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c972610, at 0x13e442f10>,
#  <GraphView object, directed, with 168 vertices and 167 edges, edges filtered by <EdgePropertyMap object with value type 'bool', for Graph 0x14c973610, at 0x149faedd0>, vertices filtered by <VertexPropertyMap object with value type 'bool', for Graph 0x14c973610, at 0x14c9c8cd0>, at 0x14c973610>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c973610, at 0x14c9a0c50>)

# %%
state_w = minimize_nested_blockmodel_dl(eG,
                                        state_args=dict(
                                            deg_corr=True,
                                            recs=[eG.edge_properties['edge_weight']],
                                            rec_types=["discrete-binomial"]))

# %%
state_w.print_summary()
# Out:
# l: 0, N: 149, B: 46
# l: 1, N: 46, B: 7
# l: 2, N: 7, B: 2
# l: 3, N: 2, B: 1
# l: 4, N: 1, B: 1

# %%
state_w2 = minimize_nested_blockmodel_dl(eG,
                                         state_args=dict(
                                             deg_corr=True,
                                             recs=[eG.edge_properties['edge_weight']],
                                             rec_types=["discrete-binomial"]),
                                         multilevel_mcmc_args=dict(B_min=12, B_max=12))

# %%
state_w2.print_summary()
# Out:
# l: 0, N: 149, B: 12
# l: 1, N: 12, B: 3
# l: 2, N: 3, B: 1
# l: 3, N: 1, B: 1

# %%
state_w2.draw(
    layout = "sfdp", 
    vertex_text = eG.vertex_properties['title'], 
    eorder = eG.edge_properties['edge_weight'],
    vertex_text_position = 315,
    bg_color=[255,255,255,1],
    output_size=[4024,4024],
    output='../figures/core_enron_blockmodel_sfdpw.png'
    )
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c972610, at 0x14c9a22d0>,
#  <GraphView object, directed, with 165 vertices and 164 edges, edges filtered by <EdgePropertyMap object with value type 'bool', for Graph 0x14c9b6b90, at 0x14fa07390>, vertices filtered by <VertexPropertyMap object with value type 'bool', for Graph 0x14c9b6b90, at 0x14c9f0490>, at 0x14c9b6b90>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c9b6b90, at 0x14fa2a950>)

# %%
employee_blocks_df = get_block_membership(state, eG, employee_df,
                                         'model_uw_1')
employee_blocks_df = get_block_membership(state_w2, eG, employee_blocks_df,
                                         'model_w_2')

# %%
df_by_position = employee_blocks_df.groupby('position').agg(list)
df_by_position[df_by_position.index.isin(['CEO','President', 'In House Lawyer'])].head()
# Out:
#                                                                 id  \
# position
# CEO              [david.w.delainey@enron.com, jeff.skilling@enr...
# In House Lawyer  [bill.rapp@enron.com, carol.clair@enron.com, d...
# President        [greg.whalley@enron.com, jeffrey.a.shankman@en...
#
#                                           model_uw_1_block_id  \
# position
# CEO                                        [69, 53, 131, 131]
# In House Lawyer  [56, 83, 41, 41, 83, 94, 53, 73, 83, 83, 73]
# President                                   [69, 69, 69, 146]
#
#                                           model_w_2_block_id
# position
# CEO                                         [14, 57, 14, 57]
# In House Lawyer  [72, 81, 31, 31, 57, 3, 57, 72, 72, 64, 31]
# President                                   [57, 57, 14, 72]

# %%
employee_blocks_df.groupby(['position'])['model_uw_1_block_id'].agg(lambda x: x.nunique()/x.count())
# Out:
# position
# Administrative Assistant    1.000000
# Analyst                     0.600000
# Associate                   1.000000
# CEO                         0.750000
# CFO                         1.000000
# COO                         1.000000
# Director                    0.411765
# Employee                    0.600000
# In House Lawyer             0.545455
# Manager                     0.400000
# Managing Director           0.833333
# President                   0.500000
# Senior Manager              1.000000
# Senior Specialist           1.000000
# Specialist                  0.500000
# Trader                      0.228571
# Vice President              0.423077
# Name: model_uw_1_block_id, dtype: float64

# %%
print(employee_blocks_df.groupby(['position'])['model_uw_1_block_id'].agg(lambda x: x.nunique()/x.count()).sum())
print(employee_blocks_df.groupby(['position'])['model_w_2_block_id'].agg(lambda x: x.nunique()/x.count()).sum())
# Out:
# 11.792200936318583
# 11.93313500225265

# %%
employee_blocks_df.groupby(['model_uw_1_block_id'])['position'].agg(lambda x: x.nunique()/x.count())
# Out:
# model_uw_1_block_id
# 21     0.727273
# 41     0.666667
# 48     0.400000
# 53     0.500000
# 56     0.583333
# 69     0.666667
# 73     0.500000
# 80     0.600000
# 83     0.428571
# 94     0.625000
# 100    0.277778
# 102    0.230769
# 131    0.833333
# 139    0.666667
# 146    0.666667
# Name: position, dtype: float64

# %%
print(employee_blocks_df.groupby(['model_uw_1_block_id'])['position'].agg(lambda x: x.nunique()/x.count()).sum())
print(employee_blocks_df.groupby(['model_w_2_block_id'])['position'].agg(lambda x: x.nunique()/x.count()).sum())
# Out:
# 8.372724497724498
# 8.363519813519813

# %%
from sklearn.metrics import homogeneity_score, completeness_score, adjusted_mutual_info_score

# %%
homogeneity_score(employee_blocks_df['position'], employee_blocks_df['model_uw_1_block_id'])
# Out:
# 0.38858029987642395

# %%
homogeneity_score(employee_blocks_df['position'], employee_blocks_df['model_w_2_block_id'])
# Out:
# 0.2106228825312484

# %%
completeness_score(employee_blocks_df['position'], employee_blocks_df['model_uw_1_block_id'])
# Out:
# 0.36141114136574864

# %%
completeness_score(employee_blocks_df['position'], employee_blocks_df['model_w_2_block_id'])
# Out:
# 0.2568323813449736

# %%
adjusted_mutual_info_score(employee_blocks_df['position'], employee_blocks_df['model_uw_1_block_id'])
# Out:
# 0.16744513050452667

# %%
adjusted_mutual_info_score(employee_blocks_df['position'], employee_blocks_df['model_w_2_block_id'])
# Out:
# 0.037143118971098704

# %%
adjusted_mutual_info_score(employee_blocks_df['model_w_2_block_id'], employee_blocks_df['model_uw_1_block_id'])
# Out:
# 0.21018976236581394

# %% [markdown]
# ##  Model Selection and Optimization

# %%
states = [minimize_nested_blockmodel_dl(eG, state_args=dict(deg_corr=True))
          for n in range(10)]

for s in states:
    print(s.entropy())
# Out:
# 6368.168791951487
# 6389.241961822571
# 6379.108443423391
# 6364.975174776477
# 6406.352038018327
# 6404.776850598389
# 6411.714329185036
# 6378.391507425756
# 6375.548993146982
# 6380.292545984561

# %%
state = states[np.argmin([s.entropy() for s in states])]

# %% [markdown]
# ## More MCMC

# %%
S1 = state.entropy()
S1
# Out:
# 6364.975174776477

# %%
state = state.copy(bs=state.get_bs() + [np.zeros(1)] * 4,sampling = True)
# Out:
# /Users/testingaccount/development/dcss_supplementary/.pixi/envs/default/lib/python3.11/site-packages/graph_tool/inference/blockmodel.py:375: UserWarning: unrecognized keyword arguments: ['sampling']
#   warnings.warn("unrecognized keyword arguments: " +

# %%
bs = []

# our callback function that appends each estimated blockstate to the array
def collect_partitions(s):
    global bs
    bs.append(s.get_bs())
        
mcmc_equilibrate(state, force_niter=10000, mcmc_args=dict(niter=10), callback=collect_partitions)
# Out:
# (6345.402368551826, 33001296, 5786052)

# %%
state.entropy() - S1
# Out:
# -19.57280622518556

# %%
pmode = PartitionModeState(bs, nested=True, converge=True)

pv = pmode.get_marginal(eG)
eG.vertex_properties['pv'] = pv

# %%
bs = pmode.get_max_nested()
state = state.copy(bs=bs)
state.entropy()
# Out:
# 6333.929156620025

# %%
employee_blocks_df = get_block_membership(state, eG, employee_blocks_df, 'model_uw_mcmc')
homogeneity_score(employee_blocks_df['position'], employee_blocks_df['model_uw_mcmc_block_id'])
# Out:
# 0.4015327373405099

# %%
completeness_score(employee_blocks_df['position'], employee_blocks_df['model_uw_mcmc_block_id'])
# Out:
# 0.3567646529120341

# %%
adjusted_mutual_info_score(employee_blocks_df['position'], employee_blocks_df['model_uw_mcmc_block_id'])
# Out:
# 0.15528961008386447

# %% [markdown]
# ## Visualizing Block Connections as a Radial Tree

# %%
state.draw(inline=True)  # render into the notebook (no GTK window)
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c972610, at 0x16cf09dd0>,
#  <GraphView object, directed, with 175 vertices and 174 edges, edges filtered by <EdgePropertyMap object with value type 'bool', for Graph 0x15f342e90, at 0x16cd07390>, vertices filtered by <VertexPropertyMap object with value type 'bool', for Graph 0x15f342e90, at 0x16cd987d0>, at 0x15f342e90>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x15f342e90, at 0x16d575550>)

# %%
eG = label_radial_blockmodel(eG, state)

# %%
state.draw(
    vertex_text = eG.vertex_properties['title'], 
    eorder = eG.edge_properties['edge_weight'],
    vertex_shape='pie',
    vertex_pie_fractions=eG.vertex_properties['pv'],
    edge_control_points = eG.edge_properties['cts'],
    pos=eG.vertex_properties['pos'], 
    vertex_size=10, 
    edge_pen_width = 0.2,
    bg_color=[255,255,255,1],
    vertex_text_rotation=eG.vertex_properties['text_rot'],
    vertex_text_position=0,
    output='../figures/core_state_radial_tree_labels.pdf'
    )
# Out:
# (<VertexPropertyMap object with value type 'vector<double>', for Graph 0x14c972610, at 0x14c9e49d0>,
#  <GraphView object, directed, with 175 vertices and 174 edges, edges filtered by <EdgePropertyMap object with value type 'bool', for Graph 0x16d642d10, at 0x16d642e10>, vertices filtered by <VertexPropertyMap object with value type 'bool', for Graph 0x16d642d10, at 0x16d6416d0>, at 0x16d642d10>,
#  <VertexPropertyMap object with value type 'vector<double>', for Graph 0x16d642d10, at 0x16d640c10>)

# %% [markdown]
# ## TopSBM: A Unified Bayesian Approach to Latent Variable Modelling for Text and Networks

# %% [markdown]
# **2026 update:** The pickled topSBM model below was created with a vendored copy of [hSBM_Topicmodel](https://github.com/martingerlach/hSBM_Topicmodel) that lived inside the dcss package when the book was written and was never distributed in this repository, and graph-tool pickles are also sensitive to the library version that created them. The loading and topic-table cells below therefore cannot run as distributed; their stored outputs show the original full-corpus results. To explore topic modelling with stochastic block models on current tooling, start from the upstream hSBM_Topicmodel repository.

# %%
topSBM_model = pickle.load( open( '../data/pickles/can_hansard_100k_sample_topSBM.pkl', 'rb'))

# %%
topic_dict = topSBM_model.topics(l=1,n=20)

# %%
df_list = []
for topic in [76,91,200,228,104,126]:
    df = pd.DataFrame.from_records(topic_dict[topic], columns = ['words_' + str(topic), 'scores_' + str(topic)])
    df_list.append(df)
topic_df = pd.concat(df_list, axis=1)
topic_df.head(20)

# %% [markdown]
# # CONCLUSION
# ## Key Points
