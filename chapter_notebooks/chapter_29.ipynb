# %% [markdown]
# # <font color="#49699E" size=40>Variational Bayes and the Craft of Generative Topic Modelling</font>

# %% [markdown]
# # LEARNING OBJECTIVES
# # LEARNING MATERIALS
# # INTRODUCTION

# %% [markdown]
# # GENERATIVE TOPIC MODELS

# %% [markdown]
# ## Latent Dirichlet Allocation (LDA)

# %% [markdown]
# ## LDA as a Graphical Model

# %% [markdown]
# ## The Dirichlet in Latent Dirichlet Allocation

# %% [markdown]
# ### Understanding the $\alpha$ hyperparameter
# ### Understanding the $\eta$ hyperparameter

# %% [markdown]
# ## Variational Inference

# %% [markdown]
# ## Selecting the Number of Topics

# %% [markdown]
# # TOPIC MODELLING WITH GENSIM

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.set_option("display.notebook_repr_html", False)
from dcss.plotting import custom_seaborn
custom_seaborn()

from dcss.text import preprocess, bow_to_df
 
from gensim import corpora
from pprint import pprint
from gensim.models import LdaModel
from gensim.models.ldamulticore import LdaMulticore
from gensim.models.coherencemodel import CoherenceModel
import pickle

# %%
df = pd.read_csv('../data/canadian_hansards/lipad/canadian_hansards.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      20000 non-null  int64
#  1   speakeroldname  19998 non-null  object
#  2   speechtext      20000 non-null  object
#  3   speakerparty    20000 non-null  object
#  4   speakerriding   20000 non-null  object
#  5   speakername     20000 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 937.6+ KB

# %%
texts = df['speechtext'].tolist()
processed_text = preprocess(texts, bigrams=False, detokenize=False, n_process = 32)

# %%
len(processed_text)
# Out:
# 20000

# %%
with open('../data/pickles/preprocessed_speeches_canadian_hansards_no_bigrams.pkl', 'wb') as handle:
    pickle.dump(processed_text, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
processed_text = pickle.load( open( '../data/pickles/preprocessed_speeches_canadian_hansards_no_bigrams.pkl', 'rb'))

# %% [markdown]
# #### Creating a Bag-of-Words with Gensim

# %%
vocab = corpora.Dictionary(processed_text) # id2word
vocab.save('../models/lda_vocab.dict')

# %%
vocab = corpora.Dictionary.load('../models/lda_vocab.dict')
vocab.filter_extremes(no_below=20, no_above=0.95)
corpus = [vocab.doc2bow(text) for text in processed_text]

# %%
len(vocab)
# Out:
# 4165

# %% [markdown]
# ## Running the Topic Model

# %%
import random
random.seed(100)

# %% [markdown]
# **2026 update:** The full Canadian Hansard corpus used in the book contains millions of speeches and is too large to distribute with this repository. The combined file this notebook loads is a 77,700-speech extract, so the cell below samples half of the locally available speeches rather than the 100,000 speeches described in the book text. The sample-versus-full workflow is unchanged.

# %%
# The book drew a 100,000-speech sample from the full Canadian Hansard corpus.
# This repository ships a smaller extract, so we subsample half of what is
# available locally to preserve the sample-versus-full comparison below.
sample_size = min(100_000, len(corpus) // 2)
sample_corpus, sample_text = zip(*random.sample(list(zip(corpus, processed_text)), sample_size))

# %%
ldamod_s = LdaModel(corpus=sample_corpus,
                      id2word=vocab,
                      num_topics=100,
                      random_state=100,
                      eval_every=1,
                      chunksize=2000,
                      alpha='auto',
                      eta='auto',
                      passes=2,
                      update_every=1,
                      iterations=400
                  )

# %%
with open('../data/pickles/lda_model_sample.pkl', 'wb') as handle:
    pickle.dump(ldamod_s, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
ldamod_s = pickle.load(open( '../data/pickles/lda_model_sample.pkl', 'rb'))

# %%
ldamod_s.get_term_topics('freedom')
# Out:
# [(4, np.float32(0.011523927)), (47, np.float32(0.020398898))]

# %%
ldamod_s.show_topic(53)
# Out:
# [('bill', np.float32(0.046480894)),
#  ('mandatory', np.float32(0.03404213)),
#  ('Edmonton', np.float32(0.033532903)),
#  ('Bill', np.float32(0.030585146)),
#  ('program', np.float32(0.024393478)),
#  ('member', np.float32(0.02163409)),
#  ('government', np.float32(0.021244708)),
#  ('willing', np.float32(0.019947968)),
#  ('day', np.float32(0.018836534)),
#  ('Service', np.float32(0.017944248))]

# %%
ldamod_s.get_term_topics('criminal')
# Out:
# [(43, np.float32(0.014968133)),
#  (52, np.float32(0.019859001)),
#  (54, np.float32(0.021517912))]

# %%
ldamod_s.show_topic(20)
# Out:
# [('family', np.float32(0.020718114)),
#  ('man', np.float32(0.020543853)),
#  ('child', np.float32(0.020354299)),
#  ('people', np.float32(0.018376)),
#  ('woman', np.float32(0.016600773)),
#  ('different', np.float32(0.015825843)),
#  ('way', np.float32(0.014208513)),
#  ('issue', np.float32(0.013635351)),
#  ('Canada', np.float32(0.013619757)),
#  ('time', np.float32(0.011231668))]

# %%
ldamod_s.get_term_topics('marriage')
# Out:
# []

# %%
ldamod_s.show_topic(28, topn=30)
# Out:
# [('indigenous', np.float32(0.27518806)),
#  ('people', np.float32(0.106945276)),
#  ('Speaker', np.float32(0.03806006)),
#  ('relationship', np.float32(0.03794991)),
#  ('Mr.', np.float32(0.035884287)),
#  ('nation', np.float32(0.031502824)),
#  ('interest', np.float32(0.027717473)),
#  ('organ', np.float32(0.024586221)),
#  ('foreign', np.float32(0.021815998)),
#  ('ocean', np.float32(0.020500286)),
#  ('action', np.float32(0.019901548)),
#  ('important', np.float32(0.017145514)),
#  ('government', np.float32(0.017099926)),
#  ('Canadians', np.float32(0.016497806)),
#  ('risk', np.float32(0.014756581)),
#  ('Bill', np.float32(0.013153371)),
#  ('meeting', np.float32(0.012883945)),
#  ('education', np.float32(0.012732593)),
#  ('good', np.float32(0.0127147585)),
#  ('interference', np.float32(0.010456356)),
#  ('jurisdiction', np.float32(0.009227562)),
#  ('bill', np.float32(0.008942126)),
#  ('track', np.float32(0.008866878)),
#  ('pleased', np.float32(0.008405551)),
#  ('consent', np.float32(0.00798701)),
#  ('community', np.float32(0.007920339)),
#  ('territory', np.float32(0.007829474)),
#  ('harvesting', np.float32(0.007751431)),
#  ('way', np.float32(0.007526867)),
#  ('north', np.float32(0.0070479433))]

# %% [markdown]
# ### Evaluating the Quality of Topic Models by Measuring Semantic Coherence

# %%
coherence_model_s = CoherenceModel(model=ldamod_s, 
                                     texts=sample_text, 
                                     dictionary=vocab, 
                                     coherence='c_v')

coherence_lda_s = coherence_model_s.get_coherence()
print('Coherence Score: ', coherence_lda_s)
# Out:
# Coherence Score:  0.37833925901856424

# %%
with open('../data/pickles/coherence_model_sample.pkl', 'wb') as handle:
    pickle.dump(coherence_model_s, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
coherence_model_s = pickle.load( open( '../data/pickles/coherence_model_sample.pkl', 'rb'))

# %%
topic_coherence_s = coherence_model_s.get_coherence_per_topic(with_std = True)
topic_coherence_df = pd.DataFrame(topic_coherence_s, columns = ['coherence','std'])
topic_coherence_df = topic_coherence_df.sort_values(['coherence', 'std'], ascending=[False,True])

# %%
topic_coherence_df.head(10).mean()
# Out:
# coherence    0.594519
# std          0.294098
# dtype: float64

# %%
topic_coherence_df.tail(10).mean()
# Out:
# coherence    0.224567
# std          0.180644
# dtype: float64

# %% [markdown]
# ### Going Further with Better Priors

# %%
alpha_asym = np.fromiter(
                    (1.0 / (i + np.sqrt(100)) for i in range(100)),
                    dtype=np.float16, count=100,
                    )
eta_sym = 1/100

# %%
alpha_t = ldamod_s.alpha
eta_t = ldamod_s.eta

# %%
print("Trained alpha variance: " + str(np.round(np.var(alpha_t), 4)))
print("Asymmetric alpha variance: " + str(np.round(np.var(alpha_asym), 4)))
print("Trained alpha avg: " + str(np.round(alpha_t.sum()/len(alpha_t), 4)))
print("Asymmetric alpha avg: " + str(np.round(alpha_asym.sum()/len(alpha_asym), 4)))

print("Trained eta variance: " + str(np.round(np.var(eta_t), 4)))
print("Symmetric eta variance: " + str(np.round(np.var(eta_sym), 4)))
print("Trained eta avg: " + str(np.round(eta_t.sum()/len(eta_t),4)))
print("Symmetric eta avg: " + str(np.round(eta_sym, 4)))
# Out:
# Trained alpha variance: 0.0
# Asymmetric alpha variance: 0.0004
# Trained alpha avg: 0.0111
# Asymmetric alpha avg: 0.0244
# Trained eta variance: 0.0002
# Symmetric eta variance: 0.0
# Trained eta avg: 0.0127
# Symmetric eta avg: 0.01

# %%
ldamod_f = LdaMulticore(corpus=corpus,
                      id2word=vocab,
                      num_topics=100,
                      random_state=100,
                      chunksize=2000,
                      alpha=alpha_t,
                      eta=eta_t,
                      passes=1,
                      iterations=10,
                      workers=None,  # use all available cores minus one
                      per_word_topics=True)

# %%
with open('../data/pickles/lda_model_full.pkl', 'wb') as handle:
    pickle.dump(ldamod_f, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
ldamod_f = pickle.load( open( '../data/pickles/lda_model_full.pkl', 'rb'))

# %%
coherence_model_full = CoherenceModel(model=ldamod_f,
                                     texts=processed_text,
                                     dictionary=vocab,
                                     coherence='c_v')
coherence_full = coherence_model_full.get_coherence()

# %%
with open('../data/pickles/coherence_model_full.pkl', 'wb') as handle:
    pickle.dump(coherence_model_full, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
coherence_model_full = pickle.load( open( '../data/pickles/coherence_model_full.pkl', 'rb'))

# %%
coherence_full
# Out:
# np.float64(0.29301530858899016)

# %%
topic_coherence_f = coherence_model_full.get_coherence_per_topic(with_std = True)
topic_coherence_f_df = pd.DataFrame(topic_coherence_f, columns = ['coherence','std'])
topic_coherence_f_df = topic_coherence_f_df.sort_values(['coherence', 'std'], ascending=[False,True])

# %%
print("Full model average coherence top 30 topics: " + str(topic_coherence_f_df['coherence'].head(30).mean()))
print("Sample model average coherence top 30 topics: " + str(topic_coherence_df['coherence'].head(30).mean()))
print("Full model average coherence bottom 30 topics: " + str(topic_coherence_f_df['coherence'].tail(30).mean()))
print("Sample model average coherence bottom 30 topics: " + str(topic_coherence_df['coherence'].tail(30).mean()))
# Out:
# Full model average coherence top 30 topics: 0.3133216120379682
# Sample model average coherence top 30 topics: 0.5189112688400905
# Full model average coherence bottom 30 topics: 0.2741511680521222
# Sample model average coherence bottom 30 topics: 0.25863283113552366

# %%
topic_coherence_f_df.head(10)
# Out:
#     coherence       std
# 96   0.342070  0.177550
# 80   0.338711  0.156223
# 35   0.322629  0.140389
# 33   0.322012  0.155741
# 17   0.321125  0.144234
# 57   0.318771  0.125279
# 52   0.316412  0.124220
# 68   0.316159  0.138863
# 48   0.316154  0.140730
# 81   0.315431  0.150277

# %%
topic_coherence_df.head(10)
# Out:
#     coherence       std
# 58   0.705167  0.276853
# 10   0.633272  0.268738
# 43   0.616901  0.291748
# 29   0.596628  0.350485
# 61   0.584118  0.253293
# 68   0.574577  0.324299
# 50   0.565371  0.363718
# 36   0.565227  0.248343
# 26   0.556079  0.228281
# 59   0.547844  0.335224

# %% [markdown]
# ### Visualizing Topic Model Output with PyLDAVis

# %%
import pyLDAvis.gensim_models as gensimvis
from pyLDAvis import save_html

# %%
vis = gensimvis.prepare(ldamod_f, corpus, vocab)

# %%
save_html(vis, '../data/misc/ldavis_full_model.html')

# %% [markdown]
# # CONCLUSION
# ## Key Points
