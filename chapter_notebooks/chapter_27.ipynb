# %% [markdown]
# # <font color="#49699E" size=40>Bayesian Regression Models with Probabilistic Programming</font>
# # LEARNING OBJECTVES
# # LEARNING MATERIALS
# # INTRODUCTION
# ## Imports

# %%
import pandas as pd
pd.set_option("display.notebook_repr_html", False)
import numpy as np
import seaborn as sns
import pymc as pm
import arviz as az

import matplotlib as mpl
from matplotlib import pyplot as plt

from dcss.plotting import custom_seaborn
custom_seaborn()

from dcss.bayes import plot_2020_election_diff, plot_2020_election_fit

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2026 update:** This chapter was written for PyMC3. The notebook now uses [PyMC](https://www.pymc.io) version 5, the actively maintained successor, imported as `import pymc as pm`. The modelling workflow is identical, but sampling functions now return ArviZ `InferenceData` objects, with samples organized into groups such as `prior`, `prior_predictive`, `posterior`, `posterior_predictive`, and `observed_data`. The code cells below have been updated accordingly wherever the book shows dictionary-style access to traces.

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('../data/2020_election/2020_districts_combined.csv')
df.head()
# Out:
#      vote        spend      state  districts  dem_inc  rep_inc  pvi
# 0 -110424  -1853145.17  Louisiana          5      0.0      0.0  -15
# 1  142997    844317.53    Vermont          0      1.0      0.0   15
# 2   87490    994256.62     Hawaii          2      0.0      0.0   19
# 3   80046  11428704.81   New York         17      0.0      0.0    7
# 4   65679   1634476.18      Texas         33      1.0      0.0   23

# %% [markdown]
# ## Checking and Cleaning the Data

# %%
pd.options.display.float_format = "{:.2f}".format

df[['vote', 'spend', 'districts']].describe()
# Out:
#             vote        spend  districts
# count     371.00       371.00     371.00
# mean    -2408.57     70377.38      10.20
# std    104536.61   2896688.38      10.57
# min   -212953.00 -23465420.95       0.00
# 25%    -92659.00  -1058899.68       3.00
# 50%     -8376.00    386021.41       6.00
# 75%     79494.50   1373394.40      13.00
# max    308869.00  11428704.81      52.00

# %%
plot_2020_election_diff(df)

# %% [markdown]
# ### Standardize Data, Process Categoricals

# %%
spend_std = (df.spend - np.mean(df.spend))/ np.std(df.spend)
vote_std = (df.vote - np.mean(df.vote))/ np.std(df.vote)
state_cat =pd.Categorical(df.state)
state_idx = state_cat.codes
n_states = len(set(state_idx))

# %% [markdown]
# # DEVELOPING OUR BAYESIAN MODEL

# %% [markdown]
# ## Making the Model with PyMC

# %% [markdown]
# ### Context Management for Modelling with PyMC

# %%
with pm.Model() as test_model: 
    testPrior = pm.Normal("testPrior", 0, 1)

# %%
test_model
# Out:
# testPrior ~ Normal(0, 1)

# %%
testPrior
# Out:
# testPrior ~ Normal(0, 1)

# %%
with test_model:
    anotherTest = pm.Normal("anotherTest", 2.5, 10)
    
test_model
# Out:
#   testPrior ~ Normal(0, 1)
# anotherTest ~ Normal(2.5, 10)

# %% [markdown]
# ### Specifying the Model in PyMC

# %%
with pm.Model() as pool_model:
    # Priors
    alpha = pm.Normal("alpha", mu=1, sigma=2)
    beta = pm.Normal("beta", mu=1, sigma=2)
    sigma = pm.Exponential("sigma", lam=2)

# %%
with pool_model:
    # Linear Model
    mu = alpha + beta * spend_std

# %%
with pool_model:
    # Likelihood
    votes = pm.Normal("votes", mu=mu, sigma=sigma, observed=vote_std)

# %% [markdown]
# ## Prior Predictive Check

# %%
with pool_model:
    prior_predictive = pm.sample_prior_predictive(
        draws=50, var_names=['alpha', 'beta', 'sigma', 'votes'], random_seed=42)

prior_predictive.groups()
# Out:
# Sampling: [alpha, beta, sigma, votes]
# ['prior', 'prior_predictive', 'observed_data']

# %%
prior_predictive.prior_predictive['votes'].shape
# Out:
# (1, 50, 371)

# %%
spend_grid = np.linspace(-20, 20, 50)

plt.xlim((-10, 10))
plt.ylim((-10, 10))

prior_alphas = prior_predictive.prior['alpha'].values.flatten()
prior_betas = prior_predictive.prior['beta'].values.flatten()
for a, b in zip(prior_alphas, prior_betas):
    # This is the same linear model that appeared in our PyMC definition above
    vote_sim = a + b * spend_grid 
    plt.plot(spend_grid, vote_sim, c="k", alpha=0.4)

plt.axhspan(-2, 2, facecolor='black', alpha=0.2)
plt.axvspan(-2, 2, facecolor='black', alpha=0.2)
    
plt.xlabel("Expenditure differential (standard deviations)")
plt.ylabel("Vote differential (standard deviations)")
plt.show()

# %%
with pm.Model() as regularized_model:

    # Priors
    alpha = pm.Normal("alpha", mu=0, sigma=0.5)
    beta = pm.Normal("beta", mu=0.5, sigma=1)
    sigma = pm.Exponential("sigma", lam=1)

    # Linear Model
    mu = alpha + beta * spend_std

    # Likelihood
    votes = pm.Normal("votes", mu=mu, sigma=sigma, observed=vote_std)

    reg_prior_pred = pm.sample_prior_predictive(
        draws=50, var_names=['alpha', 'beta', 'sigma', 'votes'], random_seed=42)
# Out:
# Sampling: [alpha, beta, sigma, votes]

# %%
spend_grid = np.linspace(-20, 20, 50)

plt.xlim((-10, 10))
plt.ylim((-10, 10))

reg_prior_alphas = reg_prior_pred.prior['alpha'].values.flatten()
reg_prior_betas = reg_prior_pred.prior['beta'].values.flatten()
for a, b in zip(reg_prior_alphas, reg_prior_betas):
    # This is the same linear model that appeared in our PyMC definition above
    vote_sim = a + b * spend_grid 
    plt.plot(spend_grid, vote_sim, c="k", alpha=0.4)

plt.axhspan(-2, 2, facecolor='black', alpha=0.2)
plt.axvspan(-2, 2, facecolor='black', alpha=0.2)
    
plt.xlabel("Expenditure differential (standard deviations)")
plt.ylabel("Vote differential (standard deviations)")
plt.show()

# %% [markdown]
# ## Running Our Model

# %%
with pool_model:
    # Run Sample Traces
    trace_pool = pm.sample()
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.

# %%
with pool_model:
    summary = az.summary(trace_pool, round_to=2)
    
summary[['mean', 'sd', 'r_hat']]
# Out:
#        mean   sd  r_hat
# alpha  0.00 0.05   1.00
# beta   0.44 0.05   1.00
# sigma  0.90 0.03   1.00

# %% [markdown]
# ## Checking the Traceplot

# %%
with pool_model:
    az.plot_trace(trace_pool, ['alpha', 'beta', 'sigma'], compact=True)

# %% [markdown]
# ## Establishing Credible Intervals

# %%
with pool_model:
    fig, axs = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(6, 6))
    az.plot_posterior(trace_pool,
                      ax=axs,
                      var_names=['alpha', 'beta', 'sigma'],
                      hdi_prob=0.89)
    fig.tight_layout()

# %% [markdown]
# ## Posterior Predictive Checks

# %%
with pool_model:
    ppc = pm.sample_posterior_predictive(trace_pool)
# Out:
# Sampling: [votes]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.plot_ppc(
    ppc,
    num_pp_samples = 100,
    legend=False
)

plt.show()

# %% [markdown]
# ## Plotting Uncertainty

# %%
plot_2020_election_fit(spend_std, vote_std, trace_pool, ppc)

# %% [markdown]
# # CONCLUSION
# ## Key Points
