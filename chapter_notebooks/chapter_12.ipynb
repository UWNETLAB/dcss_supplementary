# %% [markdown]
# # <font color="#49699E" size=40>Text Similarity and Latent Semantic Space</font>
# # LEARNING OBJECTIVES
# # LEARNING MATERIALS
# # INTRODUCTION
# ## Package Imports

# %%
import pickle
from pprint import pprint
import pandas as pd
pd.set_option("display.notebook_repr_html", False)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from dcss.text import bigram_process, preprocess, bow_to_df, get_topic_word_scores
from dcss.plotting import format_axes_commas, custom_seaborn
from dcss.utils import sparse_groupby
custom_seaborn()

import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner'])

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

# %% [markdown]
# ## TF-IDF Vectorization

# %%
with open ('../data/pickles/processed_sample_british_party_subset_hansards.pkl', 'rb') as fp:
    preprocessed = pickle.load(fp)

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=.1,
                                   min_df=3,
                                   strip_accents='ascii')

tfidf_matrix = tfidf_vectorizer.fit_transform(preprocessed) 
tfidf_matrix.shape
# Out:
# (2576, 3718)

# %% [markdown]
# **2026 update:** scikit-learn 1.2 renamed `get_feature_names` to `get_feature_names_out`. The vectorizer calls in this notebook use the new method name.

# %%
with open ('../data/pickles/brit_hansards_sample_party_subset_count_matrix.pkl', 'rb') as fp:
    count_matrix = pickle.load(fp)

tfidf_scores = np.ravel(tfidf_matrix.sum(0))
tfidf_scores = tfidf_scores/np.linalg.norm(tfidf_scores)
term_counts = np.ravel(count_matrix.sum(0))
term_counts = term_counts/np.linalg.norm(term_counts)
vocabulary = tfidf_vectorizer.get_feature_names_out()


df = pd.DataFrame({'Term': vocabulary, 'TFIDF': tfidf_scores, 'Count': term_counts})
df.sort_values(by='TFIDF', ascending=False, inplace=True)

# %%
sns.jointplot(data=df.head(5000), x='Count', y='TFIDF', kind='hist')
plt.show()
# Out:
# /var/folders/b5/h41fdq7j1ys3hmsdxf5sk9jh0000gp/T/ipykernel_45499/4127223295.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
tfidf_vectorizer = TfidfVectorizer(strip_accents='ascii', sublinear_tf=True)

tfidf_matrix = tfidf_vectorizer.fit_transform(preprocessed)
tfidf_matrix.shape
# Out:
# (2576, 10508)

# %% [markdown]
# ## Computing Semantic Similarity and Clustering Documents

# %%
with open ('../data/pickles/sampled_british_hansard_speeches.pkl', 'rb') as fp:
    speech_df = pickle.load(fp)
    
party_names = speech_df['party']
tfidf_vocabulary = tfidf_vectorizer.get_feature_names_out()
party_scores = sparse_groupby(party_names, tfidf_matrix, tfidf_vocabulary)

# %%
len(party_names)
# Out:
# 2576

# %%
normalize = Normalizer()
party_scores_n = normalize.fit_transform(party_scores)

# %%
sim_matrix = party_scores_n @ party_scores_n.T
sim_df = pd.DataFrame.sparse.from_spmatrix(sim_matrix).sparse.to_dense()

# %%
np.fill_diagonal(sim_df.values, np.nan)
sim_df.values[np.tril_indices(sim_df.shape[0], -1)] = np.nan

# %%
sim_df.index = party_scores.index
sim_df.columns = party_scores.index

# %%
print(sim_df.stack().nlargest(3))
# Out:
# Labour            Liberal Democrat           0.895779
# Liberal Democrat  Scottish National Party    0.864096
# Labour            Scottish National Party    0.857514
# dtype: float64

# %%
print(sim_df.stack().nsmallest(3))
# Out:
# Green Party                Plaid Cymru    0.406701
# Democratic Unionist Party  Plaid Cymru    0.512326
# Conservative               Plaid Cymru    0.530967
# dtype: float64

# %%
party_scores_df = pd.DataFrame.sparse.from_spmatrix(party_scores_n)
party_scores_df.index = party_scores.index
party_scores_df.columns = tfidf_vectorizer.get_feature_names_out()

for party in ['Labour','Liberal Democrat', 'Democratic Unionist Party', 'Plaid Cymru']:
    print(party + '\n')
    print(party_scores_df.loc[party].nlargest(10))
    print('\n')
# Out:
# Labour
#
# government     0.20458
# minister      0.191457
# people        0.174922
# house         0.156913
# hon            0.15513
# secretary     0.151774
# state         0.150681
# year          0.142557
# member        0.133487
# time          0.130732
# Name: Labour, dtype: Sparse[float64, 0]
#
#
# Liberal Democrat
#
# people         0.19827
# government    0.197915
# minister      0.182856
# hon           0.177192
# house         0.160536
# secretary     0.144496
# member         0.14246
# right         0.140964
# gentleman     0.132288
# state         0.131187
# Name: Liberal Democrat, dtype: Sparse[float64, 0]
#
#
# Democratic Unionist Party
#
# northern_ireland    0.360033
# minister            0.177172
# hon                 0.170295
# issue               0.161076
# people              0.156199
# house               0.148997
# secretary           0.142467
# state                0.14199
# government          0.134104
# united_kingdom      0.121593
# Name: Democratic Unionist Party, dtype: Sparse[float64, 0]
#
#
# Plaid Cymru
#
# wale          0.512939
# welsh         0.290025
# government    0.201794
# minister      0.133879
# secretary     0.120725
# british       0.117516
# uk            0.116744
# policy        0.110362
# state         0.100593
# eu            0.095174
# Name: Plaid Cymru, dtype: Sparse[float64, 0]

# %% [markdown]
# # EXPLORING LATENT SEMANTIC SPACE WITH MATRIX DECOMPOSITION

# %% [markdown]
# ## Latent Semantic Analysis (LSA) with Singular Value Decomposition (SVD)

# %% [markdown]
# ### LSA via SVD in sklearn

# %%
lsa = TruncatedSVD(n_components=100, n_iter=6, random_state=12)

# %%
lsa = lsa.fit(tfidf_matrix)

# %%
svs = lsa.singular_values_[:20]
svs
# Out:
# array([8.77853519, 4.12055504, 3.88933993, 3.49470812, 3.40210574,
#        3.23122706, 3.15545287, 2.98007164, 2.95597405, 2.89606706,
#        2.83271234, 2.81058682, 2.79259153, 2.72973614, 2.69632144,
#        2.67197702, 2.65585201, 2.60878817, 2.57726717, 2.56985943])

# %%
word_topics = pd.DataFrame(lsa.components_).T # transpose the dataframe so WORDS are in the rows
column_names = [f'Topic {c}' for c in np.arange(1,101,1)]
word_topics.columns = column_names

word_topics.shape
# Out:
# (10508, 100)

# %%
terms = tfidf_vectorizer.get_feature_names_out()
word_topics.index = terms

word_topics.sort_values(by='Topic 2', ascending = False)['Topic 2'].head(20)
# Out:
# deal              0.400811
# prime_minister    0.249169
# eu                0.240105
# brexit            0.217542
# european_union    0.156428
# trade             0.138336
# uk                0.123021
# vote              0.121306
# scotland          0.096288
# negotiation       0.093780
# parliament        0.089393
# european          0.086744
# single_market     0.086646
# scottish          0.086381
# border            0.085275
# agreement         0.085187
# state             0.084525
# house             0.083008
# secretary         0.081707
# united_kingdom    0.079319
# Name: Topic 2, dtype: float64

# %%
compare_df = pd.DataFrame()

compare_terms = ['england', 'scotland', 'wale', 'ireland']

for i, term in enumerate(compare_terms):
    scores = word_topics.loc[term].sort_values(ascending=False)
    compare_df[i] = scores.index
    compare_df[term] = scores.values

# %%
compare_df.head()
# Out:
#           0   england         1  scotland         2      wale         3  \
# 0  Topic 72  0.089021   Topic 7  0.408221  Topic 20  0.269179   Topic 8
# 1  Topic 88  0.069844  Topic 17  0.177259  Topic 32  0.255592  Topic 74
# 2  Topic 45  0.056645   Topic 9  0.152547  Topic 27  0.248970  Topic 94
# 3  Topic 12  0.052288  Topic 33  0.118821  Topic 25  0.231313  Topic 56
# 4  Topic 15  0.051805  Topic 13  0.109498  Topic 16  0.225922   Topic 2
#
#     ireland
# 0  0.086007
# 1  0.051247
# 2  0.050617
# 3  0.046233
# 4  0.040329

# %%
word_topics.loc['scotland'].sort_values(ascending=False)
# Out:
# Topic 7     0.408221
# Topic 17    0.177259
# Topic 9     0.152547
# Topic 33    0.118821
# Topic 13    0.109498
#               ...
# Topic 35   -0.120286
# Topic 67   -0.120467
# Topic 68   -0.121548
# Topic 6    -0.137345
# Topic 11   -0.140178
# Name: scotland, Length: 100, dtype: float64

# %%
get_topic_word_scores(word_topics, 10, 'Topic 8')
# Out:
# [('northern_ireland', 0.399),
#  ('gentleman', 0.3629),
#  ('border', 0.2136),
#  ('issue', 0.1686),
#  ('people', 0.1658),
#  ('minister', 0.1616),
#  ('united_kingdom', 0.1477),
#  ('irish', 0.1131),
#  ('assembly', 0.1016),
#  ('backstop', 0.1015),
#  ('child', -0.0733),
#  ('amendment', -0.0755),
#  ('deal', -0.0832),
#  ('secretary', -0.0913),
#  ('business', -0.0992),
#  ('state', -0.1005),
#  ('bill', -0.1115),
#  ('member', -0.1217),
#  ('right', -0.1602),
#  ('friend', -0.2938)]

# %% [markdown]
# # CONCLUSION
# ## Key Points
